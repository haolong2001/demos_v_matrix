# %%
import pandas as pd

# 读取死亡参数数据
death_params = pd.read_csv('../data/death_params.csv')
print("death_params.csv columns:", death_params.columns.tolist())
# Out:
# death_params.csv columns: ['sim_year', 'agent_gender', 'agent_age', 'agent_death_prob']

# %%
# this is for 1990 - 2024; 
import numpy as np
result_matrix = np.fromfile("../../data/bin/result_matrix_data.bin", dtype=np.float64)  # Specify data type if needed
result_matrix = result_matrix.reshape(8, 86, 35)  # Reshape to correct dimensions (8 cohorts, 86 ages, 35 years)

# %%
# porportion
#

# %%
ckd_porprotion = []
[1, 1.2, 1.8, 3.2, 5.9]

# find mortality rate of 2022 as well

# estimate ckd mortality rate in 2022
