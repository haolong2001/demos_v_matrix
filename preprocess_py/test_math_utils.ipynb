# %% [markdown]
# # Testing math_utils Module
#
# This notebook demonstrates how to import and use functions from the math_utils.py module.

# %%
# Import the function from math_utils module
from math_utils import add_numbers

# %%
# Test the function with integers
result1 = add_numbers(5, 3)
print(f"5 + 3 = {result1}")

# %%
# Test the function with floating point numbers
result2 = add_numbers(3.14, 2.86)
print(f"3.14 + 2.86 = {result2}")
