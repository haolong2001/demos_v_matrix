# %%
0.08207898 * 0.9
# Out:
# 0.073871082

# %%
import numpy as np
np.array([-8.210539 * 0.92, -8.380487 * 0.95, -8.030455 * 0.95, -8.065594 * 0.99,
                          -8.352823 * 0.93, -8.645856, -8.071825, -8.254004]) * 1.2
# Out:
# array([ -9.06443506,  -9.55375518,  -9.1547187 ,  -9.58192567,
#         -9.32175047, -10.3750272 ,  -9.68619   ,  -9.9048048 ])
